# %% [markdown]
# # Running Inference

# %%
# !python main.py --mode test --dataset CelebA --image_size 256 --c_dim 5 \
                 --selected_attrs Black_Hair Blond_Hair Brown_Hair Male Young \
                 --model_save_dir='../../pretrained_models/stargan_celeba_256/models' \
                 --result_dir='../../pretrained_models/stargan_celeba_256/results'
# Out:
# Namespace(attr_path='../../data/celeba/list_attr_celeba.txt', batch_size=16, beta1=0.5, beta2=0.999, c2_dim=8, c_dim=5, celeba_crop_size=178, celeba_image_dir='../../data/celeba/images', d_conv_dim=64, d_lr=0.0001, d_repeat_num=6, dataset='CelebA', g_conv_dim=64, g_lr=0.0001, g_repeat_num=6, image_size=256, lambda_cls=1, lambda_gp=10, lambda_rec=10, log_dir='../../stargan/logs', log_step=10, lr_update_step=1000, mode='test', model_save_dir='../../pretrained_models/stargan_celeba_256/models', model_save_step=10000, n_critic=5, num_iters=200000, num_iters_decay=100000, num_workers=1, rafd_crop_size=256, rafd_image_dir='../../data/RaFD/train', result_dir='../../pretrained_models/stargan_celeba_256/results', resume_iters=None, sample_dir='../../stargan/samples', sample_step=1000, selected_attrs=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'], test_iters=200000, use_tensorboard=True)
# Finished preprocessing the CelebA dataset...
# Generator(
#   (main): Sequential(
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (200,30)

img = plt.imread('../../pretrained_models/stargan_celeba_256/results/115-images.jpg')
plt.imshow(img)
